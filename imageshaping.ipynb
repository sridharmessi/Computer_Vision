# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

img = cv2.imread('C:/Users/USER/PycharmProjects/image/boundary.png',0)
plt.figure()
plt.imshow(img,cmap='gray')

kernel = np.ones((5,5),np.uint8)
img_eroded = cv2.erode(img,kernel,iterations =1)
img_dilated = cv2.dilate(img,kernel,iterations = 1)
img_opened = cv2.morphologyEx(img, cv2.MORPH_OPEN, kernel)
img_closed = cv2.morphologyEx(img, cv2.MORPH_CLOSE, kernel)

plt.figure()
plt.imshow(img_eroded,cmap='gray')
plt.title('Erosion')
plt.figure()
plt.imshow(img_dilated,cmap='gray')
plt.title('Dilation')
plt.figure()
plt.imshow(img_opened,cmap='gray')
plt.title('Opening')
plt.figure()
plt.imshow(img_closed,cmap='gray')
plt.title('Closing')
# Out:
# Text(0.5, 1.0, 'Closing')

# %%
img_boundary1 = np.subtract(img,img_eroded)
plt.figure()
plt.imshow(img_boundary1,cmap='gray')
plt.title('img_boundary1')
img_boundary2 = np.subtract(img_dilated,img)
plt.figure()
plt.imshow(img_boundary2,cmap='gray')
plt.title('img_boundary2')
img_boundary3= np.subtract(img_dilated,img_eroded)
plt.figure()
plt.imshow(img_boundary3,cmap='gray')
plt.title('img_boundary3')
# Out:
# Text(0.5, 1.0, 'img_boundary3')

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

img = cv2.imread('C:/Users/USER/PycharmProjects/image/checkerboard.png',0)
plt.figure()
plt.imshow(img,cmap='gray')

kernel = np.ones((5,5),np.uint8)
img_eroded = cv2.erode(img,kernel,iterations =1)
img_dilated = cv2.dilate(img,kernel,iterations = 1)
img_opened = cv2.morphologyEx(img, cv2.MORPH_OPEN, kernel)
img_closed = cv2.morphologyEx(img, cv2.MORPH_CLOSE, kernel)

plt.figure()
plt.imshow(img_eroded,cmap='gray')
plt.title('Erosion')
plt.figure()
plt.imshow(img_dilated,cmap='gray')
plt.title('Dilation')
plt.figure()
plt.imshow(img_opened,cmap='gray')
plt.title('Opening')
plt.figure()
plt.imshow(img_closed,cmap='gray')
plt.title('Closing')
# Out:
# Text(0.5, 1.0, 'Closing')

# %%
img_boundary1 = np.subtract(img,img_eroded)
plt.figure()
plt.imshow(img_boundary1,cmap='gray')
plt.title('img_boundary1')
img_boundary2 = np.subtract(img_dilated,img)
plt.figure()
plt.imshow(img_boundary2,cmap='gray')
plt.title('img_boundary2')
img_boundary3= np.subtract(img_dilated,img_eroded)
plt.figure()
plt.imshow(img_boundary3,cmap='gray')
plt.title('img_boundary3')
# Out:
# Text(0.5, 1.0, 'img_boundary3')

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

img = cv2.imread('C:/Users/USER/PycharmProjects/image/bound.jpeg',0)
plt.figure()
plt.imshow(img,cmap='gray')

kernel = np.ones((5,5),np.uint8)
img_eroded = cv2.erode(img,kernel,iterations =1)
img_dilated = cv2.dilate(img,kernel,iterations = 1)
img_opened = cv2.morphologyEx(img, cv2.MORPH_OPEN, kernel)
img_closed = cv2.morphologyEx(img, cv2.MORPH_CLOSE, kernel)

plt.figure()
plt.imshow(img_eroded,cmap='gray')
plt.title('Erosion')
plt.figure()
plt.imshow(img_dilated,cmap='gray')
plt.title('Dilation')
plt.figure()
plt.imshow(img_opened,cmap='gray')
plt.title('Opening')
plt.figure()
plt.imshow(img_closed,cmap='gray')
plt.title('Closing')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-458fc4d688cb> in <module>
#       5 img = cv2.imread('C:/Users/USER/PycharmProjects/image/bound.jpeg',0)
#       6 plt.figure()
# ----> 7 plt.imshow(img,cmap='gray')
#       8
#       9 kernel = np.ones((5,5),np.uint8)
#
# c:\users\user\pycharmprojects\image\venv\lib\site-packages\matplotlib\pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, filternorm, filterrad, resample, url, data, **kwargs)
#    2728         filternorm=filternorm, filterrad=filterrad, resample=resample,
#    2729         url=url, **({"data": data} if data is not None else {}),
# -> 2730         **kwargs)
#    2731     sci(__ret)
#    2732     return __ret
#
# c:\users\user\pycharmprojects\image\venv\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1445     def inner(ax, *args, data=None, **kwargs):
#    1446         if data is None:
# -> 1447             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1448
#    1449         bound = new_sig.bind(ax, *args, **kwargs)
#
# c:\users\user\pycharmprojects\image\venv\lib\site-packages\matplotlib\axes\_axes.py in imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, filternorm, filterrad, resample, url, **kwargs)
#    5521                               resample=resample, **kwargs)
#    5522
# -> 5523         im.set_data(X)
#    5524         im.set_alpha(alpha)
#    5525         if im.get_clip_path() is None:
#
# c:\users\user\pycharmprojects\image\venv\lib\site-packages\matplotlib\image.py in set_data(self, A)
#     701                 not np.can_cast(self._A.dtype, float, "same_kind")):
#     702             raise TypeError("Image data of dtype {} cannot be converted to "
# --> 703                             "float".format(self._A.dtype))
#     704
#     705         if self._A.ndim == 3 and self._A.shape[-1] == 1:
#
# TypeError: Image data of dtype object cannot be converted to float

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

img = cv2.imread('C:/Users/USER/PycharmProjects/image/bound.jpg',0)
plt.figure()
plt.imshow(img,cmap='gray')

kernel = np.ones((5,5),np.uint8)
img_eroded = cv2.erode(img,kernel,iterations =1)
img_dilated = cv2.dilate(img,kernel,iterations = 1)
img_opened = cv2.morphologyEx(img, cv2.MORPH_OPEN, kernel)
img_closed = cv2.morphologyEx(img, cv2.MORPH_CLOSE, kernel)

plt.figure()
plt.imshow(img_eroded,cmap='gray')
plt.title('Erosion')
plt.figure()
plt.imshow(img_dilated,cmap='gray')
plt.title('Dilation')
plt.figure()
plt.imshow(img_opened,cmap='gray')
plt.title('Opening')
plt.figure()
plt.imshow(img_closed,cmap='gray')
plt.title('Closing')
# Out:
# Text(0.5, 1.0, 'Closing')

# %%
img_boundary1 = np.subtract(img,img_eroded)
plt.figure()
plt.imshow(img_boundary1,cmap='gray')
plt.title('img_boundary1')
img_boundary2 = np.subtract(img_dilated,img)
plt.figure()
plt.imshow(img_boundary2,cmap='gray')
plt.title('img_boundary2')
img_boundary3= np.subtract(img_dilated,img_eroded)
plt.figure()
plt.imshow(img_boundary3,cmap='gray')
plt.title('img_boundary3')
# Out:
# Text(0.5, 1.0, 'img_boundary3')

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from scipy import ndimage #Multidimensioanal image processing
img = cv2.imread('C:/Users/USER/PycharmProjects/image/final2.jpg')

#1st Subdivision
def rgb2gray(rgb):
    r,g,b = rgb[:,:,0], rgb[:,:,1], rgb[:,:,2]
    gray = 0.2989*r + 0.5870*g + 0.1140*b
    return gray
img_g = rgb2gray(img)

sharpened_img1 = ndimage.prewitt(img_g,axis=0) #vertical
sharpened_img2 = ndimage.prewitt(img_g,axis=1) #horizontal
sharpened_img3 = ndimage.sobel(img_g,axis=0) #vertical
sharpened_img4 = ndimage.sobel(img_g,axis=1) #horizontal

plt.figure(1)
plt.imshow(img_g,cmap='gray')
plt.title("Original image")
plt.figure(2)
plt.imshow(sharpened_img1,cmap='gray')
plt.title("Prewitt-Vertical Image")
plt.figure(3)
plt.imshow(sharpened_img2,cmap='gray')
plt.title("Prewitt-Horizontal Image")
plt.figure(4)
plt.imshow(sharpened_img3,cmap='gray')
plt.title("Sobel-Vertical Image")
plt.figure(5)
plt.imshow(sharpened_img4,cmap='gray')
plt.title("Sobel-Horizontal Image")

#2nd Subdivision
d=2
a_gauss = cv2.GaussianBlur(img, (2*d+1, 2*d+1), -1)[d:-d,d:-d]
img1 = cv2.cvtColor(a_gauss, cv2.COLOR_BGR2GRAY)

edges = cv2.Canny(img1, 50, 150, apertureSize=3)
plt.figure(6)
plt.title('Edge Highlighted image')
plt.imshow(edges, cmap='gray')

lines=cv2.HoughLines(edges,1,np.pi/180,120)

for i in range(lines.shape[0]):
    for rho, theta in lines[i]:
        img = np.cos(theta)
        b = np.sin(theta)
        x0 = img*rho
        y0 = b*rho
        x1 = int(x0 + 1000*(-b))
        y1 = int(y0 + 1000*(img))
        x2 = int(x0 - 1000*(-b))
        y2 = int(y0 - 1000*(img))
        cv2.line(a_gauss,(x1,y1)import cv2
import numpy as np
import matplotlib.pyplot as plt

img = cv2.imread('C:/Users/USER/PycharmProjects/image/bound.jpg',0)
plt.figure()
plt.imshow(img,cmap='gray')

kernel = np.ones((3,3),np.uint8)
img_eroded = cv2.erode(img,kernel,iterations =1)
img_dilated = cv2.dilate(img,kernel,iterations = 1)
img_opened = cv2.morphologyEx(img, cv2.MORPH_OPEN, kernel)
img_closed = cv2.morphologyEx(img, cv2.MORPH_CLOSE, kernel)

plt.figure()
plt.imshow(img_eroded,cmap='gray')
plt.title('Erosion')
plt.figure()
plt.imshow(img_dilated,cmap='gray')
plt.title('Dilation')
plt.figure()
plt.imshow(img_opened,cmap='gray')
plt.title('Opening')
plt.figure()
plt.imshow(img_closed,cmap='gray')
plt.title('Closing')

,(x2,y2),(0,0,255),2)

plt.figure(7)
plt.title('Hough transformed-multiple lines detection')
plt.imshow(cv2.cvtColor(a_gauss, cv2.COLOR_BGR2RGB))

#3rd Subdivision
img = cv2.imread('C:/Users/USER/PycharmProjects/image/final2.jpg')

d=2
gimg=cv2.cvtColor(img, cv2.COLOR_BGR2GRAY) #converting color image to gray scale image
gimg = cv2.GaussianBlur(gimg, (2*d+1, 2*d+1), -1)[d:-d,d:-d]
#cimg = cv2.cvtColor(img,cv2.COLOR_GRAY2BGR)
circles = cv2.HoughCircles(gimg,cv2.HOUGH_GRADIENT,1,400,param1=50,param2=30,minRadius=0,maxRadius=0)
circles = np.uint16(np.around(circles))
for j in range(circles.shape[0]):
    for i in circles[j,:]:
        # draw the outer circle
        cv2.circle(img,(i[0],i[1]),i[2],(0,255,0),7)
        # draw the center of the circle
        cv2.circle(img,(i[0],i[1]),2,(0,0,255),10) #centre detection

plt.figure(8)
plt.title('Circles detection')
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
img_boundary1 = np.subtract(img,img_eroded)
plt.figure()
plt.imshow(img_boundary1,cmap='gray')
plt.title('img_boundary1')
img_boundary2 = np.subtract(img_dilated,img)
plt.figure()
plt.imshow(img_boundary2,cmap='gray')
plt.title('img_boundary2')
img_boundary3= np.subtract(img_dilated,img_eroded)
plt.figure()
plt.imshow(img_boundary3,cmap='gray')
plt.title('img_boundary3')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-658e33bcadec> in <module>
# ----> 1 img_boundary1 = np.subtract(img,img_eroded)
#       2 plt.figure()
#       3 plt.imshow(img_boundary1,cmap='gray')
#       4 plt.title('img_boundary1')
#       5 img_boundary2 = np.subtract(img_dilated,img)
#
# ValueError: operands could not be broadcast together with shapes (172,310,3) (1580,2106)

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

img = cv2.imread('C:/Users/USER/PycharmProjects/image/final2.jpg',0)
plt.figure()
plt.imshow(img,cmap='gray')

kernel = np.ones((3,3),np.uint8)
img_eroded = cv2.erode(img,kernel,iterations =1)
img_dilated = cv2.dilate(img,kernel,iterations = 1)
img_opened = cv2.morphologyEx(img, cv2.MORPH_OPEN, kernel)
img_closed = cv2.morphologyEx(img, cv2.MORPH_CLOSE, kernel)

plt.figure()
plt.imshow(img_eroded,cmap='gray')
plt.title('Erosion')
plt.figure()
plt.imshow(img_dilated,cmap='gray')
plt.title('Dilation')
plt.figure()
plt.imshow(img_opened,cmap='gray')
plt.title('Opening')
plt.figure()
plt.imshow(img_closed,cmap='gray')
plt.title('Closing')
# Out:
# Text(0.5, 1.0, 'Closing')

# %%
img_boundary1 = np.subtract(img,img_eroded)
plt.figure()
plt.imshow(img_boundary1,cmap='gray')
plt.title('img_boundary1')
img_boundary2 = np.subtract(img_dilated,img)
plt.figure()
plt.imshow(img_boundary2,cmap='gray')
plt.title('img_boundary2')
img_boundary3= np.subtract(img_dilated,img_eroded)
plt.figure()
plt.imshow(img_boundary3,cmap='gray')
plt.title('img_boundary3')
# Out:
# Text(0.5, 1.0, 'img_boundary3')

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from scipy import ndimage # Multi-dimensional image processing
img=mpimg.imread('C:/Users/USER/PycharmProjects/image/final.jpeg')
def rgb2gray(rgb):
 r, g, b = rgb[:,:,0], rgb[:,:,1], rgb[:,:,2]
 gray = 0.2989 * r + 0.5870 * g + 0.1140 * b
 return gray
img=rgb2gray(img)
img_noise = img + 50* np.random.randn(*img.shape)
blurred_img1=ndimage.gaussian_filter(img_noise, sigma=1.5) #Multidimensional Gaussian filter
plt.figure(1)
plt.imshow(img,cmap='gray')
plt.title("Original image")
plt.figure(2)
plt.imshow(img_noise,cmap='gray')
plt.title("Noisy image")
plt.figure(3)
plt.imshow(blurred_img1,cmap='gray')
plt.title("Gaussian filtered image")
# Out:
# Text(0.5, 1.0, 'Gaussian filtered image')
